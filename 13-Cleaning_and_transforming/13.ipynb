# %%
library(learningr)
# Out:
# Warning message:
# "package 'learningr' was built under R version 3.4.3"

# %%
?Filter

# %%
library(stringr)

# %%
multiple_kingdoms <- str_detect(english_monarchs$domain, fixed(','))
multiple_kingdoms
# Out:
#   [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [13] FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#  [25]  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE
#  [85]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE
#  [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
english_monarchs[multiple_kingdoms, c('name', 'domain')]
# Out:
#    name                        domain
# 17 Offa                        East Anglia, Mercia
# 18 Offa                        East Anglia, Kent, Mercia
# 19 Offa and Ecgfrith           East Anglia, Kent, Mercia
# 20 Ecgfrith                    East Anglia, Kent, Mercia
# 22 C<U+009C>nwulf              East Anglia, Kent, Mercia
# 23 C<U+009C>nwulf and Cynehelm East Anglia, Kent, Mercia
# 24 C<U+009C>nwulf              East Anglia, Kent, Mercia
# 25 Ceolwulf                    East Anglia, Kent, Mercia
# 26 Beornwulf                   East Anglia, Mercia
# 82 Ecgbehrt and Æthelwulf      Kent, Wessex
# 83 Ecgbehrt and Æthelwulf      Kent, Mercia, Wessex
# 84 Ecgbehrt and Æthelwulf      Kent, Wessex
# 85 Æthelwulf and Æðelstan I    Kent, Wessex
# 86 Æthelwulf                   Kent, Wessex
# 87 Æthelwulf and Æðelberht III Kent, Wessex
# 88 Æðelberht III               Kent, Wessex
# 89 Æthelred I                  Kent, Wessex
# 95 Oswiu                       Mercia, Northumbria

# %%
multiple_rulers <- str_detect(english_monarchs$name, ',|and')
multiple_rulers
# Out:
#   [1] FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE
#  [13] FALSE  TRUE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE  TRUE FALSE
#  [25] FALSE FALSE FALSE FALSE FALSE    NA FALSE FALSE FALSE FALSE FALSE FALSE
#  [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE FALSE
#  [49] FALSE FALSE    NA FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [61] FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE
#  [73]  TRUE  TRUE  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE
#  [85]  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE FALSE
#  [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [109] FALSE FALSE FALSE    NA  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE
# [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
!is.na(multiple_rulers)
# Out:
#   [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [13]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [25]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [37]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [49]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [61]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [73]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [85]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [97]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [109]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [121]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [133]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# ...

# %%
english_monarchs$name[multiple_rulers & !is.na(multiple_rulers)]
# Out:
#  [1] Sigeberht and Ecgric
#  [2] Hun, Beonna and Alberht
#  [3] Offa and Ecgfrith
#  [4] C<U+009C>nwulf and Cynehelm
#  [5] Sighere and Sebbi
#  [6] Sigeheard and Swaefred
#  [7] Eorcenberht and Eormenred
#  [8] Oswine, Swæfbehrt, Swæfheard
#  [9] Swæfbehrt, Swæfheard, Wihtred
# [10] Æðelberht II, Ælfric and Eadberht I
# [11] Æðelberht II and Eardwulf
# [12] Eadberht II, Eanmund and Sigered
# [13] Heaberht and Ecgbehrt II
# [14] Ecgbehrt and Æthelwulf
# [15] Ecgbehrt and Æthelwulf
# [16] Ecgbehrt and Æthelwulf
# [17] Æthelwulf and Æðelstan I
# [18] Æthelwulf and Æðelberht III
# [19] Penda and Eowa
# [20] Penda and Peada
# [21] Æthelred, Lord of the Mercians
# [22] Æthelflæd, Lady of the Mercians
# [23] Ælfwynn, Second Lady of the Mercians
# [24] Hálfdan and Eowils
# [25] Noðhelm and Watt
# [26] Noðhelm and Bryni
# [27] Noðhelm and Osric
# [28] Noðhelm and Æðelstan
# [29] Ælfwald, Oslac and Osmund
# [30] Ælfwald, Ealdwulf, Oslac and Osmund
# ...

# %%
individual_rulers <- str_split(english_monarchs$name, ', | ')
individual_rulers
# Out:
# [[1]]
# [1] "Wehha"
#
# [[2]]
# [1] "Wuffa"
#
# [[3]]
# [1] "Tytila"
#
# [[4]]
# [1] "Rædwald"
#
# [[5]]
# [1] "Eorpwald"
#
# [[6]]
# [1] "Ricberht"
#
# [[7]]
# [1] "Sigeberht" "and"       "Ecgric"
#
# [[8]]
# [1] "Ecgric"
#
# [[9]]
# [1] "Anna"
#
# [[10]]
# [1] "Æthelhere"
#
# [[11]]
# [1] "Æthelwold"
#
# [[12]]
# [1] "Ealdwulf"
#
# [[13]]
# [1] "Ælfwald"
#
# [[14]]
# [1] "Hun"     "Beonna"  "and"     "Alberht"
#
# [[15]]
# [1] "Æthelred" "I"
#
# [[16]]
# [1] "Æthelberht" "II"
#
# [[17]]
# [1] "Offa"
#
# [[18]]
# [1] "Offa"
#
# [[19]]
# [1] "Offa"     "and"      "Ecgfrith"
#
# [[20]]
# [1] "Ecgfrith"
#
# [[21]]
# [1] "Eadwald"
#
# [[22]]
# [1] "C<U+009C>nwulf"
#
# [[23]]
# [1] "C<U+009C>nwulf" "and"          "Cynehelm"
#
# [[24]]
# [1] "C<U+009C>nwulf"
#
# [[25]]
# [1] "Ceolwulf"
#
# [[26]]
# [1] "Beornwulf"
#
# [[27]]
# [1] "Æthelstan"
#
# [[28]]
# [1] "Æthelweard"
#
# [[29]]
# [1] "Edmund"
#
# [[30]]
# [1] NA
#
# [[31]]
# [1] "Oswald"
#
# [[32]]
# [1] "Æthelred" "II"
#
# [[33]]
# ...

# %%
individual_rulers[sapply(individual_rulers, length) > 1]
# Out:
# [[1]]
# [1] "Sigeberht" "and"       "Ecgric"
#
# [[2]]
# [1] "Hun"     "Beonna"  "and"     "Alberht"
#
# [[3]]
# [1] "Æthelred" "I"
#
# [[4]]
# [1] "Æthelberht" "II"
#
# [[5]]
# [1] "Offa"     "and"      "Ecgfrith"
#
# [[6]]
# [1] "C<U+009C>nwulf" "and"          "Cynehelm"
#
# [[7]]
# [1] "Æthelred" "II"
#
# [[8]]
# [1] "Guthrum" "II"
#
# [[9]]
# [1] "Sigeberht" "the"       "Little"
#
# [[10]]
# [1] "Sigeberht" "the"       "Good"
#
# [[11]]
# [1] "Sighere" "and"     "Sebbi"
#
# [[12]]
# [1] "Sigeheard" "and"       "Swaefred"
#
# [[13]]
# [1] "Æðelberht" "I"
#
# [[14]]
# [1] "Eorcenberht" "and"         "Eormenred"
#
# [[15]]
# [1] "Ecgbehrt" "I"
#
# [[16]]
# [1] "Oswine"    "Swæfbehrt" "Swæfheard"
#
# [[17]]
# [1] "Swæfbehrt" "Swæfheard" "Wihtred"
#
# [[18]]
# [1] "Æðelberht" "II"        "Ælfric"    "and"       "Eadberht"  "I"
#
# [[19]]
# [1] "Æðelberht" "II"        "and"       "Eardwulf"
#
# [[20]]
# [1] "Eadberht" "II"       "Eanmund"  "and"      "Sigered"
#
# [[21]]
# ...

# %%
english_monarchs$name[str_count(english_monarchs$name, 'th') == 2 & 
                      !is.na(english_monarchs$name)]
# Out:
# [1] Æthelred, Lord of the Mercians  Æthelflæd, Lady of the Mercians
# [3] Æthelfrith                      Æthelred the Unready
# [5] Æthelred the Unready            Edgar the Ætheling
# 211 Levels: Adda Æðelbehrt Æðelberht I ... Wulfhere

# %%
english_monarchs <- within(
english_monarchs,
abcdef <- end.of.reign - start.of.reign)

# %%
english_monarchs
# Out:
#     name                        house               start.of.reign end.of.reign
# 1   Wehha                       Wuffingas            NA            571
# 2   Wuffa                       Wuffingas           571            578
# 3   Tytila                      Wuffingas           578            616
# 4   Rædwald                     Wuffingas           616            627
# 5   Eorpwald                    Wuffingas           627            627
# 6   Ricberht                    Wuffingas           627            630
# 7   Sigeberht and Ecgric        Wuffingas           630            634
# 8   Ecgric                      Wuffingas           634             NA
# 9   Anna                        Wuffingas            NA            653
# 10  Æthelhere                   Wuffingas           653            655
# 11  Æthelwold                   Wuffingas           655            663
# 12  Ealdwulf                    Wuffingas           663            713
# ...

# %%
has_all <- complete.cases(deer_endocranial_volume)
deer_endocranial_volume[has_all, ]
# Out:
#    SkullID VolCT VolBead VolLWH VolFinarelli VolCT2 VolBead2 VolLWH2
# 7  C120    346   335     1250   289          346    330      1264
# 8  C25     302   295     1011   250          303    295      1009
# 9  F7      379   360     1621   347          375    365      1647
# 10 B12     410   400     1740   387          413    395      1728
# 11 B17     405   395     1652   356          408    395      1639
# 12 B18     391   370     1835   419          394    375      1825
# 13 J7      416   405     1834   408          417    405      1876
# 15 A4      336   330     1224   283          345    330      1192
# 20 K2      349   355     1239   286          354    365      1243

# %%
deer_wide <- deer_endocranial_volume[, 1:5]

# %%
library(reshape2)
deer_long <- melt(deer_wide, id.vars = 'SkullID')
head(deer_long)
# Out:
#   SkullID variable value
# 1 DIC44   VolCT    389
# 2 B11     VolCT    389
# 3 DIC90   VolCT    352
# 4 DIC83   VolCT    388
# 5 DIC787  VolCT    375
# 6 DIC1573 VolCT    325

# %%
?is.positive

# %%
# 13.1
data(hafu, package = 'learningr')

# %%
hafu <- mutate(
hafu,
has_question_father = str_detect(Father, fixed('?')),
has_question_mother = str_detect(Mother, fixed('?'))
)
hafu
# Out:
#     Year Series                         Character                   Gender
# 1   1963 Yuki no Taiyou                 Sanae                       F
# 2   1964 Cyborg 009                     Joe Shimamura               M
# 3   1967 Lupin III                      Lupin III                   M
# 4   1967 Nekome Kozou                   Cat-Eyed Boy                M
# 5   1972 Gatchaman                      Jun the Swan                F
# 6   1974 Great Mazinger                 Jun Hono                    F
# 7   1975 Ichigo Monogatari              Ichigo                      F
# 8   1976 Kochira Katsushika-ku...       Reiko Katherine Akimoto     F
# 9   1977 Haikara-san ga Tooru           Shinobu Iijyuin             M
# 10  1979 Mobile Suit Gundam             Amuro Ray                   M
# 11  1981 GoShogun                       Remy Shimada                F
# 12  1982 Macross                        Lynn Minmay                 F
# ...

# %%
?str_detect

# %%
?grepl

# %%
library(stringr)
hafu$Father <- str_replace(hafu$Father, fixed('?'), '')
hafu$Mother <- str_replace(hafu$Mother, fixed('?'), '')
hafu
# Out:
#     Year Series                         Character                   Gender
# 1   1963 Yuki no Taiyou                 Sanae                       F
# 2   1964 Cyborg 009                     Joe Shimamura               M
# 3   1967 Lupin III                      Lupin III                   M
# 4   1967 Nekome Kozou                   Cat-Eyed Boy                M
# 5   1972 Gatchaman                      Jun the Swan                F
# 6   1974 Great Mazinger                 Jun Hono                    F
# 7   1975 Ichigo Monogatari              Ichigo                      F
# 8   1976 Kochira Katsushika-ku...       Reiko Katherine Akimoto     F
# 9   1977 Haikara-san ga Tooru           Shinobu Iijyuin             M
# 10  1979 Mobile Suit Gundam             Amuro Ray                   M
# 11  1981 GoShogun                       Remy Shimada                F
# 12  1982 Macross                        Lynn Minmay                 F
# ...

# %%
# 4.2
library(reshape2)

# %%
dim(hafu)
# Out:
# [1] 296  11

# %%
hafu_long <- melt(hafu, measure.vars = c('Father', 'Mother'))
dim(hafu_long)
# Out:
# Warning message:
# "attributes are not identical across measure variables; they will be dropped"
# [1] 592  11

# %%
attributes(hafu$Father)
# Out:
# $levels
#  [1] "American"       "American?"      "Arabian"        "Australian"
#  [5] "Brazilian?"     "Canadian"       "Chinese"        "Chinese?"
#  [9] "Dutch"          "Egyptian?"      "English"        "English?"
# [13] "Fantasy"        "Fantasy?"       "French"         "French?"
# [17] "German"         "German?"        "Indian?"        "Irish"
# [21] "Italian"        "Japanese"       "Japanese?"      "Latin-American"
# [25] "Russian"        "Russian?"       "Scandinavian?"  "Spanish"
# [29] "Swedish"
#
# $class
# [1] "factor"

# %%
attributes(hafu$Mother)
# Out:
# $levels
#  [1] "American"   "American?"  "Brazilian"  "Canadian"   "Chinese"
#  [6] "Dutch"      "English"    "English?"   "Fantasy"    "Finnish?"
# [11] "French"     "French?"    "German"     "German?"    "Greek?"
# [16] "Irish"      "Italian"    "Japanese"   "Japanese?"  "Latin?"
# [21] "Mexican?"   "Mongolian"  "Portuguese" "Romanian?"  "Russian"
# [26] "Russian?"   "Spanish?"   "Swedish"    "Swiss"
#
# $class
# [1] "factor"

# %%
levels(hafu$Mother)
# Out:
#  [1] "American"   "American?"  "Brazilian"  "Canadian"   "Chinese"
#  [6] "Dutch"      "English"    "English?"   "Fantasy"    "Finnish?"
# [11] "French"     "French?"    "German"     "German?"    "Greek?"
# [16] "Irish"      "Italian"    "Japanese"   "Japanese?"  "Latin?"
# [21] "Mexican?"   "Mongolian"  "Portuguese" "Romanian?"  "Russian"
# [26] "Russian?"   "Spanish?"   "Swedish"    "Swiss"

# %%
arrange(hafu, )

# %%
?order

# %%
counts = count(hafu$Mother)
arrange(counts, freq, decreasing = TRUE)
# Out:
#    x          freq
# 1  Japanese   91
# 2  NA         50
# 3  Japanese?  29
# 4  English    21
# 5  French     16
# 6  American   15
# 7  German     10
# 8  American?   8
# 9  English?    8
# 10 Fantasy     8
# 11 Russian     6
# 12 French?     4
# 13 Italian     4
# 14 Russian?    4
# 15 Brazilian   3
# 16 Finnish?    2
# 17 German?     2
# 18 Spanish?    2
# 19 Swedish     2
# 20 Canadian    1
# 21 Chinese     1
# 22 Dutch       1
# 23 Greek?      1
# 24 Irish       1
# 25 Latin?      1
# 26 Mexican?    1
# 27 Mongolian   1
# 28 Portuguese  1
# 29 Romanian?   1
# 30 Swiss       1

# %%
drop

# %%
# 4.3
sort(table(hafu$Year), decreasing = TRUE)[1:10]
# Out:
# 2007 2008 2009 2004 2002 2005 2003 2000 2010 2011
#   27   23   22   21   19   19   18   13   12   12

# %%
?table
